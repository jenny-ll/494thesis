# %% [markdown]
# # Organizing Trade Data
#
# The goal of this file is to organize trade data to be merged with the final dataset along with IQ.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob
from requests import RequestException
import csv
import re
import json
import copy
import ast
import operator
import math
import time
import zipfile as zf
from collections import Counter

# %% [markdown]
# ## Step 1. Load EXIO to HS bridge dict
#
# This was provided by EXIOBASE 3 concordance table. Some HS codes have multiple exiobase products associated with it. When creating the dict, I use the first exiobase product that is associated with the HS code product to eventually calculate its emissions.

# %%
bridge = pd.read_excel('../Data/3_Trade/hs96_exio20_bridge.xlsx')
bridge.columns = ['hs1996',
                 'exiobase_20',
                 'exiobase_20_2']
bridge
# Out:
#        hs1996 exiobase_20 exiobase_20_2
# 0     10111.0       p01.l           NaN
# 1     10119.0       p01.l           NaN
# 2     10120.0       p01.l           NaN
# 3     10210.0       p01.i           NaN
# 4     10290.0       p01.i           NaN
# ...       ...         ...           ...
# 5157      NaN         NaN           p80
# 5158      NaN         NaN           p85
# 5159      NaN         NaN           p91
# 5160      NaN         NaN           p95
# 5161      NaN         NaN           p99
#
# [5162 rows x 3 columns]

# %%
# create list of tuples using exiobase_20 and hs1996

bridge_tuples = list(bridge[['hs1996', 'exiobase_20']].itertuples(index=False, name=None))
len(bridge_tuples)
# Out:
# 5162

# %%
# list of tuples for the exiobase_20_2 column and hs1996

bridge_tuples_2 = list(bridge[['hs1996', 'exiobase_20_2']].itertuples(index=False, name=None))
bridge_tuples_no_nan = [t for t in bridge_tuples_2 if not any(isinstance(n, float) and math.isnan(n) for n in t)]
#remove nans

# %%
#combine lists

full_bridge = bridge_tuples_no_nan + bridge_tuples
full_bridge
# Out:
# [(290362.0, 'p23.20.k'),
#  (321590.0, 'p24.f'),
#  (340311.0, 'p24.f'),
#  (340319.0, 'p24.f'),
#  (340391.0, 'p24.f'),
#  (340399.0, 'p24.f'),
#  (340600.0, 'p36'),
#  (340700.0, 'p24.f'),
#  (380210.0, 'p24.f'),
#  (380910.0, 'p24.f'),
#  (380991.0, 'p24.f'),
#  (380992.0, 'p24.f'),
#  (380993.0, 'p24.f'),
#  (381010.0, 'p24.f'),
#  (381090.0, 'p24.f'),
#  (381210.0, 'p24.f'),
#  (381220.0, 'p24.f'),
#  (381230.0, 'p24.f'),
#  (381300.0, 'p24.f'),
#  (381511.0, 'p24.f'),
#  (381512.0, 'p24.f'),
#  (381519.0, 'p24.f'),
#  (381590.0, 'p24.f'),
#  (381710.0, 'p24.f'),
#  (381720.0, 'p24.f'),
#  (381800.0, 'p24.f'),
#  (381900.0, 'p24.f'),
#  (382000.0, 'p24.f'),
#  (382100.0, 'p24.f'),
#  (382200.0, 'p24.f'),
#  (382410.0, 'p24.f'),
#  (382420.0, 'p24.f'),
#  (382430.0, 'p24.f'),
#  (382440.0, 'p24.f'),
#  (382460.0, 'p24.f'),
#  (382471.0, 'p24.f'),
#  (382479.0, 'p24.f'),
#  (440130.0, 'p20.w'),
#  (470710.0, 'p21.w.1'),
#  (470720.0, 'p21.w.1'),
#  (470730.0, 'p21.w.1'),
#  (470790.0, 'p21.w.1'),
#  (391510.0, 'p24.a.w'),
#  (121120.0, 'p01.h'),
#  (121190.0, 'p01.h'),
#  (100110.0, 'p01.b'),
#  (100190.0, 'p01.b'),
#  (100200.0, 'p01.c'),
#  (100300.0, 'p01.c'),
#  (100400.0, 'p01.c'),
#  (100510.0, 'p01.c'),
#  (100590.0, 'p01.c'),
#  (100610.0, 'p01.a'),
#  (100620.0, 'p15.g'),
#  (100630.0, 'p15.g'),
#  (100640.0, 'p15.g'),
#  (100700.0, 'p01.c'),
#  (100810.0, 'p01.c'),
#  (100820.0, 'p01.c'),
#  (100830.0, 'p01.c'),
#  (100890.0, 'p01.c'),
#  (110100.0, 'p15.i'),
#  (110210.0, 'p15.i'),
#  (110220.0, 'p15.i'),
#  (110230.0, 'p15.i'),
#  (110290.0, 'p15.i'),
#  (110311.0, 'p15.i'),
#  (110312.0, 'p15.i'),
#  (110313.0, 'p15.i'),
#  (110314.0, 'p15.i'),
#  (110319.0, 'p15.i'),
#  (110321.0, 'p15.i'),
#  (110329.0, 'p15.i'),
#  (110411.0, 'p15.i'),
#  (110412.0, 'p15.i'),
#  (110419.0, 'p15.i'),
#  (110421.0, 'p15.i'),
#  (110422.0, 'p15.i'),
#  (110423.0, 'p15.i'),
#  (110429.0, 'p15.i'),
#  (110430.0, 'p15.i'),
#  (110510.0, 'p15.i'),
#  (110520.0, 'p15.i'),
#  (110610.0, 'p15.i'),
#  (110620.0, 'p15.i'),
#  (110630.0, 'p15.i'),
#  (110710.0, 'p15.j'),
#  (110720.0, 'p15.j'),
#  (110811.0, 'p15.i'),
#  (110812.0, 'p15.i'),
#  (110813.0, 'p15.i'),
#  (110814.0, 'p15.i'),
#  (110819.0, 'p15.i'),
#  (110820.0, 'p15.i'),
#  (110900.0, 'p15.i'),
#  (120100.0, 'p01.e'),
#  (120210.0, 'p01.e'),
#  (120220.0, 'p01.e'),
#  (120300.0, 'p01.e'),
#  (120400.0, 'p01.e'),
#  (120500.0, 'p01.e'),
#  (120600.0, 'p01.e'),
#  (120710.0, 'p01.e'),
#  (120720.0, 'p01.e'),
#  (120730.0, 'p01.e'),
#  (120740.0, 'p01.e'),
#  (120750.0, 'p01.e'),
#  (120760.0, 'p01.e'),
#  (120791.0, 'p01.e'),
#  (120792.0, 'p01.e'),
#  (120799.0, 'p01.e'),
#  (120810.0, 'p15.e'),
#  (120890.0, 'p15.e'),
#  (120911.0, 'p01.h'),
#  (120919.0, 'p01.h'),
#  (120921.0, 'p01.h'),
#  (120922.0, 'p01.h'),
#  (120923.0, 'p01.h'),
#  (120924.0, 'p01.h'),
#  (120925.0, 'p01.h'),
#  (120926.0, 'p01.h'),
#  (120929.0, 'p01.h'),
#  (120930.0, 'p01.h'),
#  (120991.0, 'p01.h'),
#  (120999.0, 'p01.h'),
#  (121010.0, 'p01.h'),
#  (121020.0, 'p15.i'),
#  (121210.0, 'p01.d'),
#  (121220.0, 'p05'),
#  (121230.0, 'p15.i'),
#  (121291.0, 'p01.f'),
#  (121292.0, 'p01.f'),
#  (121299.0, 'p01.d'),
#  (121300.0, 'p01.h'),
#  (121410.0, 'p15.i'),
#  (251120.0, 'p14.3'),
#  (251200.0, 'p14.3'),
#  (251311.0, 'p14.3'),
#  (251319.0, 'p14.3'),
#  (251320.0, 'p14.3'),
#  (251400.0, 'p14.1'),
#  (251511.0, 'p14.1'),
#  (251512.0, 'p14.1'),
#  (251520.0, 'p14.1'),
#  (251611.0, 'p14.1'),
#  (251612.0, 'p14.1'),
#  (251621.0, 'p14.1'),
#  (251622.0, 'p14.1'),
#  (251690.0, 'p14.1'),
#  (251710.0, 'p14.2'),
#  (251720.0, 'p14.2'),
#  (251730.0, 'p14.2'),
#  (251741.0, 'p14.2'),
#  (251749.0, 'p14.2'),
#  (251810.0, 'p14.1'),
#  (251820.0, 'p14.1'),
#  (251830.0, 'p14.1'),
#  (251910.0, 'p14.3'),
#  (251990.0, 'p14.3'),
#  (252010.0, 'p14.1'),
#  (252020.0, 'p26.d'),
#  (252100.0, 'p14.1'),
#  (252210.0, 'p26.d'),
#  (252220.0, 'p26.d'),
#  (252230.0, 'p26.d'),
#  (252310.0, 'p26.d'),
#  (252321.0, 'p26.d'),
#  (252329.0, 'p26.d'),
#  (252330.0, 'p26.d'),
#  (252390.0, 'p26.d'),
#  (252400.0, 'p14.3'),
#  (252510.0, 'p14.3'),
#  (252520.0, 'p14.3'),
#  (252530.0, 'p14.3'),
#  (252610.0, 'p14.3'),
#  (252620.0, 'p14.3'),
#  (252700.0, 'p14.3'),
#  (252810.0, 'p14.3'),
#  (252890.0, 'p14.3'),
#  (252910.0, 'p14.3'),
#  (252921.0, 'p14.3'),
#  (252922.0, 'p14.3'),
#  (252930.0, 'p14.3'),
#  (253010.0, 'p14.3'),
#  (253020.0, 'p14.3'),
#  (253040.0, 'p14.3'),
#  (253090.0, 'p14.3'),
#  (260111.0, 'p13.1'),
#  (260112.0, 'p13.1'),
#  (260120.0, 'p24.d'),
#  (260200.0, 'p13.20.16'),
#  (260300.0, 'p13.20.11'),
#  (260400.0, 'p13.20.12'),
#  (260500.0, 'p13.20.16'),
#  (260600.0, 'p13.20.13'),
#  (260700.0, 'p13.20.15'),
#  (260800.0, 'p13.20.15'),
#  (260900.0, 'p13.20.15'),
#  (261000.0, 'p13.20.16'),
#  (261100.0, 'p13.20.16'),
#  (261210.0, 'p12'),
#  (261220.0, 'p12'),
#  (261310.0, 'p13.20.16'),
#  (261390.0, 'p13.20.16'),
#  (261400.0, 'p13.20.16'),
#  (261510.0, 'p13.20.16'),
#  (261590.0, 'p13.20.16'),
#  (261610.0, 'p13.20.14'),
#  (261690.0, 'p13.20.14'),
#  (261710.0, 'p13.20.16'),
#  (261790.0, 'p13.20.16'),
#  (262011.0, 'p27.43'),
#  (262019.0, 'p27.43'),
#  (262020.0, 'p27.43'),
#  (262030.0, 'p27.44'),
#  (262040.0, 'p27.42'),
#  (262050.0, 'p27.45'),
#  (262090.0, 'p27.45'),
#  (262100.0, 'p14.3'),
#  (270111.0, 'p10.a'),
#  (270119.0, 'p10.a'),
#  (270112.0, 'p10.c'),
#  (270112.0, 'p10.d'),
#  (270119.0, 'p10.c'),
#  (270119.0, 'p10.b'),
#  (270119.0, 'p10.e'),
#  (270120.0, 'p10.e'),
#  (270120.0, 'p10.g'),
#  (270210.0, 'p10.f'),
#  (270220.0, 'p10.f'),
#  (270300.0, 'p10.g'),
#  (270300.0, 'p10.h'),
#  (270400.0, 'p23.1.a'),
#  (270400.0, 'p23.1.b'),
#  (270500.0, 'p40.2.a'),
#  (270500.0, 'p40.2.b'),
#  (270500.0, 'p40.2.c'),
#  (270500.0, 'p40.2.d'),
#  (270500.0, 'p40.2.e'),
#  (270600.0, 'p23.1.c'),
#  (270710.0, 'p24.d'),
#  (270720.0, 'p24.d'),
#  (270730.0, 'p24.d'),
#  (270740.0, 'p24.d'),
#  (270750.0, 'p24.d'),
#  (270760.0, 'p24.d'),
#  (270791.0, 'p24.d'),
#  (270799.0, 'p24.d'),
#  (270810.0, 'p24.d'),
#  (270820.0, 'p24.d'),
#  (270900.0, 'p11.a'),
#  (271000.0, 'p23.20.a'),
#  (271000.0, 'p23.20.b'),
#  (271000.0, 'p23.20.c'),
#  (271000.0, 'p23.20.d'),
#  (271000.0, 'p23.20.e'),
#  (271000.0, 'p23.20.f'),
#  (271000.0, 'p23.20.g'),
#  (271000.0, 'p23.20.l'),
#  (271000.0, 'p23.20.m'),
#  (271111.0, 'p11.b.1'),
#  (271112.0, 'p23.20.i'),
#  (271113.0, 'p23.20.i'),
#  (271114.0, 'p23.20.i'),
#  (271119.0, 'p23.20.i'),
#  (271121.0, 'p11.b'),
#  (271129.0, 'p11.b'),
#  (271129.0, 'p11.c'),
#  (271129.0, 'p23.20.h'),
#  (271210.0, 'p23.20.n'),
#  (271210.0, 'p23.20.r'),
#  (271220.0, 'p23.20.p'),
#  (271290.0, 'p23.20.r'),
#  (271311.0, 'p23.20.q'),
#  (271312.0, 'p23.20.q'),
#  (271320.0, 'p23.20.j'),
#  (271320.0, 'p23.20.o'),
#  (271390.0, 'p23.20.r'),
#  (271410.0, 'p11.c'),
#  (271490.0, 'p23.20.o'),
#  (271500.0, 'p26.e'),
#  (271600.0, 'p40.11.a'),
#  (271600.0, 'p40.11.b'),
#  (271600.0, 'p40.11.c'),
#  (271600.0, 'p40.11.d'),
#  (271600.0, 'p40.11.e'),
#  (271600.0, 'p40.11.f'),
#  (271600.0, 'p40.11.g'),
#  (271600.0, 'p40.11.h'),
#  (271600.0, 'p40.11.i'),
#  (271600.0, 'p40.11.j'),
#  (271600.0, 'p40.11.k'),
#  (271600.0, 'p40.11.l'),
#  (280110.0, 'p24.d'),
#  (280120.0, 'p24.d'),
#  (280130.0, 'p24.d'),
#  (280200.0, 'p24.d'),
#  (280300.0, 'p24.d'),
#  (280410.0, 'p24.d'),
#  (280421.0, 'p24.d'),
#  (280429.0, 'p24.d'),
#  (280430.0, 'p24.d'),
#  (280440.0, 'p24.d'),
#  (280450.0, 'p24.d'),
#  (280461.0, 'p24.d'),
#  (280469.0, 'p24.d'),
#  (280470.0, 'p24.d'),
#  (280480.0, 'p24.d'),
#  (280490.0, 'p24.d'),
#  (280511.0, 'p24.d'),
#  (280519.0, 'p24.d'),
#  (280521.0, 'p24.d'),
#  (280522.0, 'p24.d'),
#  (280530.0, 'p24.d'),
#  (280540.0, 'p24.d'),
#  (280610.0, 'p24.d'),
#  (280620.0, 'p24.d'),
#  (280700.0, 'p24.d'),
#  (280800.0, 'p24.c'),
#  (280910.0, 'p24.d'),
#  (280920.0, 'p24.d'),
#  (281000.0, 'p24.d'),
#  (281111.0, 'p24.d'),
#  (281119.0, 'p24.d'),
#  (281121.0, 'p24.d'),
#  (281122.0, 'p24.d'),
#  (281123.0, 'p24.d'),
#  (281129.0, 'p24.d'),
#  (281210.0, 'p24.d'),
#  (281290.0, 'p24.d'),
#  (281310.0, 'p24.d'),
#  (281390.0, 'p24.d'),
#  (281410.0, 'p24.c'),
#  (281420.0, 'p24.c'),
#  (281511.0, 'p24.d'),
#  (281512.0, 'p24.d'),
#  (281520.0, 'p24.d'),
#  (281530.0, 'p24.d'),
#  (281610.0, 'p24.d'),
#  (281620.0, 'p24.d'),
#  (281630.0, 'p24.d'),
#  (281700.0, 'p24.d'),
#  (281810.0, 'p26.e'),
#  (281820.0, 'p27.42'),
#  (281830.0, 'p24.d'),
#  (281910.0, 'p24.d'),
#  (281990.0, 'p24.d'),
#  (282010.0, 'p24.d'),
#  (282090.0, 'p24.d'),
#  (282110.0, 'p24.d'),
#  ...]

# %%
# transform to dict format. notice that some exiocodes are used multiple times. This is OK.

full_bridge_dict = dict(full_bridge)
full_bridge_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ba4a75f65540> in <module>
#       1 # transform to dict format. notice that some exiocodes are used multiple times. This is OK.
#       2
# ----> 3 full_bridge_dict = dict(full_bridge)
#       4 full_bridge_dict
#
# NameError: name 'full_bridge' is not defined

# %%
len(full_bridge_dict)
# Out:
# 5118

# %%
hs_list = list(full_bridge_dict.keys())

# %%
len(hs_list)
# Out:
# 5118

# %% [markdown]
# # Combine all carbon files saved from from OrganizeExiobase (2002-2010 files)

# %%
path = '../Data/2_Carbon/product_carbon_emissions'
all_files = glob.glob(path + '/*.csv')

df = pd.concat((pd.read_csv(f) for f in all_files))
df
# Out:
#      country                                       product_name     total_co2  \
# 0        AUT                                         Paddy rice  9.239437e+04
# 1        AUT                                              Wheat  2.243920e+06
# 2        AUT                                  Cereal grains nec  5.929492e+06
# 3        AUT                            Vegetables, fruit, nuts  1.035572e+07
# 4        AUT                                          Oil seeds  1.027177e+07
# ...      ...                                                ...           ...
# 7982     NaN              Transportation services via pipelines  2.976391e+08
# 7983     NaN      Sea and coastal water transportation services  4.057356e+08
# 7984     NaN               Inland water transportation services  2.548728e+08
# 7985     NaN                        Air transport services (62)  4.388331e+07
# 7986     NaN  Supporting and auxiliary transport services; t...  0.000000e+00
#
#      exio_code  year
# 0        p01.a  2008
# 1        p01.b  2008
# 2        p01.c  2008
# 3        p01.d  2008
# 4        p01.e  2008
# ...        ...   ...
# 7982     p60.3  2005
# 7983     p61.1  2005
# 7984     p61.2  2005
# 7985       p62  2005
# 7986       p63  2005
#
# [71883 rows x 5 columns]

# %%
df2 = df.sort_values(by=['year', 'country', 'exio_code'], ignore_index=True)
df2
# Out:
#       country                                       product_name  \
# 0         AUS                                         Paddy rice
# 1         AUS                                              Wheat
# 2         AUS                                  Cereal grains nec
# 3         AUS                            Vegetables, fruit, nuts
# 4         AUS                                          Oil seeds
# ...       ...                                                ...
# 71878     NaN  Biogasification of food waste, incl. land appl...
# 71879     NaN   Biogasification of paper, incl. land application
# 71880     NaN  Biogasification of sewage slugde, incl. land a...
# 71881     NaN   Composting of food waste, incl. land application
# 71882     NaN  Composting of paper and wood, incl. land appli...
#
#           total_co2 exio_code  year
# 0      4.997036e+05     p01.a  2002
# 1      4.535901e+06     p01.b  2002
# 2      2.498314e+06     p01.c  2002
# 3      6.050536e+07     p01.d  2002
# 4      2.725058e+05     p01.e  2002
# ...             ...       ...   ...
# 71878  3.962346e+04       NaN  2010
# 71879  1.834599e+03       NaN  2010
# 71880  9.562182e+05       NaN  2010
# 71881  1.342422e+06       NaN  2010
# 71882  6.267667e+04       NaN  2010
#
# [71883 rows x 5 columns]

# %% [markdown]
# # Remove NaN
#
# will need to take a closer look at this later. Why are there NaN in the first place?

# %%
# name no_regions because this file does not include RestOfWorld regions that EXIOBASE originally used

df_no_regions = df2[df2['country'].notna()]
df_no_regions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d43c4c91996e> in <module>
#       1 # df_no_regions = df2[df2['country'].notna()]
# ----> 2 df_no_regions
#
# NameError: name 'df_no_regions' is not defined

# %% [markdown]
# #### Some products are not properly mapped onto their exio_code due to different wording in the concordance table. I manually find these products and map the corresponding code to them, which can later be mapped to HS6 properly (instead of wrongly being dropped as NaN)

# %%
df_no_regions.loc[df_no_regions['product_name'] == "Manure treatment (conventional), storage and land application", 'exio_code'] = 'p01.w.1'
df_no_regions.loc[df_no_regions['product_name'] == "Manure treatment (biogas), storage and land application", 'exio_code'] = 'p01.w.2'
# reprocessing is basically just replaced with recycling in the concordance tables
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary wood material into new wood material", 'exio_code'] = 'p20.w'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary paper into new pulp", 'exio_code'] = 'p21.w.1'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary plastic into new plastic", 'exio_code'] = 'p24.a.w'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary glass into new glass", 'exio_code'] = 'p26.a.w'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of ash into clinker", 'exio_code'] = 'p26.d.w'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary steel into new steel", 'exio_code'] = 'p27.a.w'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary preciuos metals into new preciuos metals", 'exio_code'] = 'p27.41.w'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary aluminium into new aluminium", 'exio_code'] = 'p27.42.w'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary lead into new lead, zinc and tin", 'exio_code'] = 'p27.43.w'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary copper into new copper", 'exio_code'] = 'p27.44.w'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary other non-ferrous metals into new other non-ferrous metals", 'exio_code'] = 'p27.45.w'
df_no_regions.loc[df_no_regions['product_name'] == "Recycling of bottles by direct reuse", 'exio_code'] = 'p37.w.1'
df_no_regions.loc[df_no_regions['product_name'] == "Re-processing of secondary construction material into aggregates", 'exio_code'] = 'p45.w'
df_no_regions.loc[df_no_regions['product_name'] == "Biogasification of food waste, incl. land application", 'exio_code'] = 'p90.2.a'
df_no_regions.loc[df_no_regions['product_name'] == "Biogasification of paper, incl. land application", 'exio_code'] = 'p90.2.b'
df_no_regions.loc[df_no_regions['product_name'] == "Biogasification of sewage slugde, incl. land application", 'exio_code'] = 'p90.2.c'
df_no_regions.loc[df_no_regions['product_name'] == "Composting of food waste, incl. land application", 'exio_code'] = 'p90.3.a'
df_no_regions.loc[df_no_regions['product_name'] == "Composting of paper and wood, incl. land application", 'exio_code'] = 'p90.3.b'
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_no_regions
# Out:
#       country                                       product_name  \
# 0         AUS                                         Paddy rice
# 1         AUS                                              Wheat
# 2         AUS                                  Cereal grains nec
# 3         AUS                            Vegetables, fruit, nuts
# 4         AUS                                          Oil seeds
# ...       ...                                                ...
# 71063     ZAF  Biogasification of food waste, incl. land appl...
# 71064     ZAF   Biogasification of paper, incl. land application
# 71065     ZAF  Biogasification of sewage slugde, incl. land a...
# 71066     ZAF   Composting of food waste, incl. land application
# 71067     ZAF  Composting of paper and wood, incl. land appli...
#
#           total_co2 exio_code  year
# 0      4.997036e+05     p01.a  2002
# 1      4.535901e+06     p01.b  2002
# 2      2.498314e+06     p01.c  2002
# 3      6.050536e+07     p01.d  2002
# 4      2.725058e+05     p01.e  2002
# ...             ...       ...   ...
# 71063  1.845703e+01   p90.2.a  2010
# 71064  3.427721e+00   p90.2.b  2010
# 71065  2.843830e+02   p90.2.c  2010
# 71066  8.752299e+02   p90.3.a  2010
# 71067  4.100791e+00   p90.3.b  2010
#
# [64548 rows x 5 columns]

# %%
# add country code

country_nos = pd.read_csv('../Data/3_Trade/country_codes_V202102.csv', encoding='latin-1')

# %%
countrynumber_dict = pd.Series(country_nos.country_code.values,index=country_nos.iso_3digit_alpha).to_dict()
countrynumber_dict
# Out:
# {'AFG': 4,
#  'ALB': 8,
#  'DZA': 12,
#  'ASM': 16,
#  'AND': 20,
#  'AGO': 24,
#  'ATG': 28,
#  'AZE': 31,
#  'ARG': 32,
#  'AUS': 36,
#  'AUT': 40,
#  'BHS': 44,
#  'BHR': 48,
#  'BGD': 50,
#  'ARM': 51,
#  'BRB': 52,
#  'BEL': 58,
#  'BMU': 60,
#  'BTN': 64,
#  'BOL': 68,
#  'BIH': 70,
#  'BWA': 72,
#  'BRA': 76,
#  'BLZ': 84,
#  'IOT': 86,
#  'SLB': 90,
#  'VGB': 92,
#  'BRN': 96,
#  'BGR': 100,
#  'MMR': 104,
#  'BDI': 108,
#  'BLR': 112,
#  'KHM': 116,
#  'CMR': 120,
#  'CAN': 124,
#  'CPV': 132,
#  'CYM': 136,
#  'CAF': 140,
#  'LKA': 144,
#  'TCD': 148,
#  'CHL': 152,
#  'CHN': 156,
#  'CXR': 162,
#  'CCK': 166,
#  'COL': 170,
#  'COM': 174,
#  'MYT': 175,
#  'COG': 178,
#  'COD': 180,
#  'COK': 184,
#  'CRI': 188,
#  'HRV': 191,
#  'CUB': 192,
#  'CYP': 196,
#  'CSK': 200,
#  'CZE': 203,
#  'BEN': 204,
#  'DNK': 208,
#  'DMA': 212,
#  'DOM': 214,
#  'ECU': 218,
#  'SLV': 222,
#  'GNQ': 226,
#  'ETH': 231,
#  'EST': 233,
#  'FLK': 238,
#  'FJI': 242,
#  'FIN': 246,
#  'FRA': 251,
#  'PYF': 258,
#  'ATF': 260,
#  'DJI': 262,
#  'GAB': 266,
#  'GEO': 268,
#  'GMB': 270,
#  'PSE': 275,
#  'DEU': 280,
#  'DDR': 278,
#  'GHA': 288,
#  'GIB': 292,
#  'KIR': 296,
#  'GRC': 300,
#  'GRL': 304,
#  'GRD': 308,
#  'GUM': 316,
#  'GTM': 320,
#  'GIN': 324,
#  'GUY': 328,
#  'HTI': 332,
#  'HND': 340,
#  'HKG': 344,
#  'HUN': 348,
#  'ISL': 352,
#  'IDN': 360,
#  'IRN': 364,
#  'IRQ': 368,
#  'IRL': 372,
#  'ISR': 376,
#  'ITA': 381,
#  'CIV': 384,
#  'JAM': 388,
#  'JPN': 392,
#  'KAZ': 398,
#  'JOR': 400,
#  'KEN': 404,
#  'PRK': 408,
#  'KOR': 410,
#  'KWT': 414,
#  'KGZ': 417,
#  'LAO': 418,
#  'LBN': 422,
#  'LSO': 426,
#  'LVA': 428,
#  'LBR': 430,
#  'LBY': 434,
#  'LTU': 440,
#  'LUX': 442,
#  'MAC': 446,
#  'MDG': 450,
#  'MWI': 454,
#  'MYS': 458,
#  'MDV': 462,
#  'MLI': 466,
#  'MLT': 470,
#  'MRT': 478,
#  'MUS': 480,
#  'MEX': 484,
#  nan: 849,
#  'MNG': 496,
#  'MDA': 498,
#  'MNE': 499,
#  'MSR': 500,
#  'MAR': 504,
#  'MOZ': 508,
#  'OMN': 512,
#  'NAM': 516,
#  'NRU': 520,
#  'NPL': 524,
#  'NLD': 528,
#  'ANT': 530,
#  'CUW': 531,
#  'ABW': 533,
#  'SXM': 534,
#  'BES': 535,
#  'NCL': 540,
#  'VUT': 548,
#  'NZL': 554,
#  'NIC': 558,
#  'NER': 562,
#  'NGA': 566,
#  'NIU': 570,
#  'NFK': 574,
#  'NOR': 579,
#  'MNP': 580,
#  'FSM': 583,
#  'MHL': 584,
#  'PLW': 585,
#  'PAK': 586,
#  'PAN': 591,
#  'PNG': 598,
#  'PRY': 600,
#  'PER': 604,
#  'PHL': 608,
#  'PCN': 612,
#  'POL': 616,
#  'PRT': 620,
#  'GNB': 624,
#  'TLS': 626,
#  'QAT': 634,
#  'ROU': 642,
#  'RUS': 643,
#  'RWA': 646,
#  'BLM': 652,
#  'SHN': 654,
#  'KNA': 659,
#  'AIA': 660,
#  'LCA': 662,
#  'SPM': 666,
#  'VCT': 670,
#  'SMR': 674,
#  'STP': 678,
#  'SAU': 682,
#  'SEN': 686,
#  'SRB': 688,
#  'SYC': 690,
#  'SLE': 694,
#  'IND': 699,
#  'SGP': 702,
#  'SVK': 703,
#  'VNM': 704,
#  'SVN': 705,
#  'SOM': 706,
#  'ZAF': 711,
#  'ZWE': 716,
#  'ESP': 724,
#  'SSD': 728,
#  'SDN': 736,
#  'SUR': 740,
#  'SWZ': 748,
#  'SWE': 752,
#  'CHE': 757,
#  'SYR': 760,
#  'TJK': 762,
#  'THA': 764,
#  'TGO': 768,
#  'TKL': 772,
#  'TON': 776,
#  'TTO': 780,
#  'ARE': 784,
#  'TUN': 788,
#  'TUR': 792,
#  'TKM': 795,
#  'TCA': 796,
#  'TUV': 798,
#  'UGA': 800,
#  'UKR': 804,
#  'MKD': 807,
#  'SUN': 810,
#  'EGY': 818,
#  'GBR': 826,
#  'TZA': 834,
#  'USA': 842,
#  'BFA': 854,
#  'URY': 858,
#  'UZB': 860,
#  'VEN': 862,
#  'WLF': 876,
#  'WSM': 882,
#  'YEM': 887,
#  'SCG': 891,
#  'ZMB': 894}

# %%
df_no_regions['country_number'] = df_no_regions['country'].map(countrynumber_dict)
df_no_regions
# Out:
# <ipython-input-19-42a1a81f1748>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_regions['country_number'] = df_no_regions['country'].map(countrynumber_dict)
#       country                                       product_name  \
# 0         AUS                                         Paddy rice
# 1         AUS                                              Wheat
# 2         AUS                                  Cereal grains nec
# 3         AUS                            Vegetables, fruit, nuts
# 4         AUS                                          Oil seeds
# ...       ...                                                ...
# 71063     ZAF  Biogasification of food waste, incl. land appl...
# 71064     ZAF   Biogasification of paper, incl. land application
# 71065     ZAF  Biogasification of sewage slugde, incl. land a...
# 71066     ZAF   Composting of food waste, incl. land application
# 71067     ZAF  Composting of paper and wood, incl. land appli...
#
#           total_co2 exio_code  year  country_number
# 0      4.997036e+05     p01.a  2002              36
# 1      4.535901e+06     p01.b  2002              36
# 2      2.498314e+06     p01.c  2002              36
# 3      6.050536e+07     p01.d  2002              36
# 4      2.725058e+05     p01.e  2002              36
# ...             ...       ...   ...             ...
# 71063  1.845703e+01   p90.2.a  2010             711
# 71064  3.427721e+00   p90.2.b  2010             711
# 71065  2.843830e+02   p90.2.c  2010             711
# 71066  8.752299e+02   p90.3.a  2010             711
# 71067  4.100791e+00   p90.3.b  2010             711
#
# [64548 rows x 6 columns]

# %%
df_no_regions.to_csv('../Data/3_Trade/product_emissions_with_exiocode.csv',index=False)

# %%
list_of_countries = df_no_regions.country_number.unique()

# %% [markdown]
# # Load BACI, containing bilateral trade flows
#
# Be careful: the next few cells take 3 hours to load.

# %%
baci_df = pd.DataFrame(columns=['t','i','j','k','v','q'])

for df in pd.read_csv('../Data/3_Trade/BACI_Tradeflow_HS02/02_10_tradeflows.csv', chunksize=500000):
    results = df[df['k'].isin(hs_list) & df['i'].isin(list_of_countries) & df['j'].isin(list_of_countries)]
    baci_df = pd.concat([baci_df, results])

# %%
baci_df.head(80)

# %%
# potential improvement: move this when iterating over chunks when parsing data
new_new_df = baci_df.loc[((baci_df['t'] == 2002) |
                         (baci_df['t'] == 2003) |
                        (baci_df['t'] == 2004) |
                        (baci_df['t'] == 2005) |
                        (baci_df['t'] == 2006) |
                        (baci_df['t'] == 2007) |
                        (baci_df['t'] == 2008) |
                        (baci_df['t'] == 2009) |
                        (baci_df['t'] == 2010))]
new_new_df
# Out:
#   File "<tokenize>", line 3
#     (baci_df['t'] == 2004) |
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#label columns informatively
new_new_df.columns = ['year', 'exporter', 'importer', 'HS_code', 'monetary_value_of_trade_flow', 'quantity_tons']

# %% [markdown]
# # Preparing and merging carbon and trade data

# %%
new_new_df

# %%
newindex_df = new_new_df.reset_index()

# %%
del newindex_df['index']

# %%
newindex_df.head()

# %%
#save filtered BACI
newindex_df.to_csv('../Data/3_Trade/new_df_trade.csv',index=False)

# %% [markdown]
# # Due to the complexity concerns with BACI and limitations of the kernel, manipulating new_df_trade.csv will be in OrganizeTradaData2
